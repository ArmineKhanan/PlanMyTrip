# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"There are {len(cities)} cities in our database")
# Out:
# There are 733 cities in our database

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# import the requests library
import requests
# Import the OpenWeatherMap's API key
from config import weather_api_key
# weather_api_key = 'bb13fdceacbec1e4654831daabaeff68'

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bb13fdceacbec1e4654831daabaeff68

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        latitude = city_weather["coord"]['lat']
        longitude = city_weather["coord"]['lon']
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        cloudiness = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
            
        # Append the city information into the city_data list
        
        city_data.append({
            "City": city.title(),
            "Lat":latitude,
            "Lng":longitude,
            "Max Temp":max_temp,
            "Humidity":humidity,
            "Cloudiness":cloudiness,
            "Wind Speed":wind,
            "Country":country,
            "Current Description":weather_description
        })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 1 | kolga
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | joshimath
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | hami
# Processing Record 13 of Set 1 | kaitangata
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | lakatoro
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | mokhsogollokh
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | port hardy
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 1 | shimoda
# Processing Record 27 of Set 1 | charters towers
# Processing Record 28 of Set 1 | chai badan
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | berlevag
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | kommunisticheskiy
# Processing Record 35 of Set 1 | dudinka
# Processing Record 36 of Set 1 | saldanha
# Processing Record 37 of Set 1 | la ronge
# Processing Record 38 of Set 1 | haines junction
# Processing Record 39 of Set 1 | ancud
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | igboho
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | chau doc
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | tucurui
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | copiapo
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | krasnoselkup
# Processing Record 6 of Set 2 | korla
# Processing Record 7 of Set 2 | luderitz
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | nemuro
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | yishui
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | lima
# Processing Record 14 of Set 2 | usinsk
# Processing Record 15 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | pozo colorado
# Processing Record 18 of Set 2 | taoudenni
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | beyneu
# Processing Record 21 of Set 2 | kuusamo
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | zhaocheng
# City not found. Skipping...
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | mogadishu
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | vardo
# Processing Record 30 of Set 2 | burica
# City not found. Skipping...
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | kotelnich
# Processing Record 33 of Set 2 | waterloo
# Processing Record 34 of Set 2 | ginir
# Processing Record 35 of Set 2 | el reten
# Processing Record 36 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 2 | qingquan
# Processing Record 38 of Set 2 | otofuke
# Processing Record 39 of Set 2 | okhotsk
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | sur
# Processing Record 43 of Set 2 | saint-louis
# Processing Record 44 of Set 2 | rincon
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | celestun
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | marawi
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | klyuchi
# Processing Record 5 of Set 3 | sangar
# Processing Record 6 of Set 3 | ilulissat
# Processing Record 7 of Set 3 | meulaboh
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | cascais
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | san cristobal
# Processing Record 13 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 15 of Set 3 | japura
# Processing Record 16 of Set 3 | san julian
# Processing Record 17 of Set 3 | klaksvik
# Processing Record 18 of Set 3 | morondava
# Processing Record 19 of Set 3 | tasiilaq
# Processing Record 20 of Set 3 | dicabisagan
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | yerbogachen
# Processing Record 24 of Set 3 | tazovskiy
# Processing Record 25 of Set 3 | takoradi
# Processing Record 26 of Set 3 | bedi
# Processing Record 27 of Set 3 | baykit
# Processing Record 28 of Set 3 | nanga eboko
# Processing Record 29 of Set 3 | hasaki
# Processing Record 30 of Set 3 | boddam
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | tuatapere
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | dingle
# Processing Record 35 of Set 3 | chimore
# Processing Record 36 of Set 3 | paracuru
# Processing Record 37 of Set 3 | quixada
# Processing Record 38 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 3 | xai-xai
# Processing Record 40 of Set 3 | uige
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 3 | deputatskiy
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | inirida
# Processing Record 45 of Set 3 | camacha
# Processing Record 46 of Set 3 | sitio novo do tocantins
# Processing Record 47 of Set 3 | shangrao
# Processing Record 48 of Set 3 | nalut
# Processing Record 49 of Set 3 | padang
# Processing Record 50 of Set 3 | narsaq
# Processing Record 1 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 4 | san jose
# Processing Record 3 of Set 4 | bathsheba
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | leshan
# Processing Record 6 of Set 4 | nagato
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | vestmannaeyjar
# Processing Record 9 of Set 4 | komsomolskiy
# Processing Record 10 of Set 4 | ulaangom
# Processing Record 11 of Set 4 | pangnirtung
# Processing Record 12 of Set 4 | waipawa
# Processing Record 13 of Set 4 | georgetown
# Processing Record 14 of Set 4 | port moresby
# Processing Record 15 of Set 4 | esperance
# Processing Record 16 of Set 4 | aksu
# Processing Record 17 of Set 4 | nishihara
# Processing Record 18 of Set 4 | rawlins
# Processing Record 19 of Set 4 | ust-ishim
# Processing Record 20 of Set 4 | beloha
# Processing Record 21 of Set 4 | grand island
# Processing Record 22 of Set 4 | brownsville
# Processing Record 23 of Set 4 | slave lake
# Processing Record 24 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | vega de alatorre
# Processing Record 28 of Set 4 | mar del plata
# Processing Record 29 of Set 4 | shelburne
# Processing Record 30 of Set 4 | kruisfontein
# Processing Record 31 of Set 4 | bilma
# Processing Record 32 of Set 4 | paamiut
# Processing Record 33 of Set 4 | clyde river
# Processing Record 34 of Set 4 | ikongo
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | kungalv
# Processing Record 37 of Set 4 | may pen
# Processing Record 38 of Set 4 | rock sound
# Processing Record 39 of Set 4 | mahebourg
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | angoche
# Processing Record 42 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 43 of Set 4 | nyurba
# Processing Record 44 of Set 4 | masalli
# Processing Record 45 of Set 4 | fairbanks
# Processing Record 46 of Set 4 | atambua
# Processing Record 47 of Set 4 | votice
# Processing Record 48 of Set 4 | muisne
# Processing Record 49 of Set 4 | buchanan
# Processing Record 50 of Set 4 | bukama
# Processing Record 1 of Set 5 | mairi
# Processing Record 2 of Set 5 | ust-kut
# Processing Record 3 of Set 5 | chapais
# Processing Record 4 of Set 5 | nacala
# Processing Record 5 of Set 5 | san quintin
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | saint george
# Processing Record 8 of Set 5 | marondera
# Processing Record 9 of Set 5 | richards bay
# Processing Record 10 of Set 5 | santa cruz de tenerife
# Processing Record 11 of Set 5 | qarqin
# Processing Record 12 of Set 5 | katihar
# Processing Record 13 of Set 5 | port alfred
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | plettenberg bay
# Processing Record 16 of Set 5 | rodding
# Processing Record 17 of Set 5 | mazatlan
# Processing Record 18 of Set 5 | san jeronimo
# Processing Record 19 of Set 5 | tahoua
# Processing Record 20 of Set 5 | krugersdorp
# Processing Record 21 of Set 5 | miyako
# Processing Record 22 of Set 5 | pilar
# Processing Record 23 of Set 5 | codrington
# Processing Record 24 of Set 5 | alekseyevsk
# Processing Record 25 of Set 5 | najran
# Processing Record 26 of Set 5 | tautira
# Processing Record 27 of Set 5 | san policarpo
# Processing Record 28 of Set 5 | sakhnovshchyna
# Processing Record 29 of Set 5 | yellowknife
# Processing Record 30 of Set 5 | gat
# Processing Record 31 of Set 5 | raton
# Processing Record 32 of Set 5 | constitucion
# Processing Record 33 of Set 5 | santa rosa
# Processing Record 34 of Set 5 | san antonio
# Processing Record 35 of Set 5 | norman wells
# Processing Record 36 of Set 5 | ilo
# Processing Record 37 of Set 5 | abnub
# Processing Record 38 of Set 5 | mocuba
# Processing Record 39 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 40 of Set 5 | kavieng
# Processing Record 41 of Set 5 | port lincoln
# Processing Record 42 of Set 5 | turan
# Processing Record 43 of Set 5 | yulara
# Processing Record 44 of Set 5 | coronel fabriciano
# Processing Record 45 of Set 5 | avarua
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | praya
# Processing Record 48 of Set 5 | brae
# Processing Record 49 of Set 5 | banepa
# Processing Record 50 of Set 5 | rio gallegos
# Processing Record 1 of Set 6 | praia
# Processing Record 2 of Set 6 | biak
# Processing Record 3 of Set 6 | arman
# Processing Record 4 of Set 6 | inhambane
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | auray
# Processing Record 7 of Set 6 | sungaipenuh
# Processing Record 8 of Set 6 | magadan
# Processing Record 9 of Set 6 | candolim
# Processing Record 10 of Set 6 | le mars
# Processing Record 11 of Set 6 | victoria
# Processing Record 12 of Set 6 | kuching
# Processing Record 13 of Set 6 | gwadar
# Processing Record 14 of Set 6 | santo antonio do ica
# Processing Record 15 of Set 6 | tagusao
# Processing Record 16 of Set 6 | luangwa
# Processing Record 17 of Set 6 | iqaluit
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | college
# Processing Record 20 of Set 6 | saint-pierre
# Processing Record 21 of Set 6 | pevek
# Processing Record 22 of Set 6 | itarema
# Processing Record 23 of Set 6 | vila franca do campo
# Processing Record 24 of Set 6 | ribas do rio pardo
# Processing Record 25 of Set 6 | port macquarie
# Processing Record 26 of Set 6 | nome
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | medea
# Processing Record 29 of Set 6 | torokszentmiklos
# Processing Record 30 of Set 6 | galle
# Processing Record 31 of Set 6 | naples
# Processing Record 32 of Set 6 | hermon
# Processing Record 33 of Set 6 | puri
# Processing Record 34 of Set 6 | san juan de los lagos
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | chernyshevskiy
# Processing Record 37 of Set 6 | kirakira
# Processing Record 38 of Set 6 | palmer
# Processing Record 39 of Set 6 | necochea
# Processing Record 40 of Set 6 | soyo
# Processing Record 41 of Set 6 | longyearbyen
# Processing Record 42 of Set 6 | tarakan
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | matto
# City not found. Skipping...
# Processing Record 45 of Set 6 | yenagoa
# Processing Record 46 of Set 6 | torbay
# Processing Record 47 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 6 | waingapu
# Processing Record 49 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 7 | pisco
# Processing Record 2 of Set 7 | mizan teferi
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | naivasha
# Processing Record 5 of Set 7 | price
# Processing Record 6 of Set 7 | changji
# Processing Record 7 of Set 7 | ranong
# Processing Record 8 of Set 7 | hella
# Processing Record 9 of Set 7 | alofi
# Processing Record 10 of Set 7 | concepcion
# Processing Record 11 of Set 7 | new norfolk
# Processing Record 12 of Set 7 | eyl
# Processing Record 13 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 7 | bastia
# Processing Record 15 of Set 7 | roald
# Processing Record 16 of Set 7 | san andres
# Processing Record 17 of Set 7 | kushmurun
# Processing Record 18 of Set 7 | oranjemund
# Processing Record 19 of Set 7 | ostrovnoy
# Processing Record 20 of Set 7 | zhanakorgan
# Processing Record 21 of Set 7 | grafton
# Processing Record 22 of Set 7 | hirara
# Processing Record 23 of Set 7 | terrace
# Processing Record 24 of Set 7 | yar-sale
# Processing Record 25 of Set 7 | santa cruz
# Processing Record 26 of Set 7 | kalispell
# Processing Record 27 of Set 7 | mount isa
# Processing Record 28 of Set 7 | cidreira
# Processing Record 29 of Set 7 | alice springs
# Processing Record 30 of Set 7 | ahuimanu
# Processing Record 31 of Set 7 | zasheyek
# Processing Record 32 of Set 7 | lydenburg
# Processing Record 33 of Set 7 | hailey
# Processing Record 34 of Set 7 | shar
# Processing Record 35 of Set 7 | flinders
# Processing Record 36 of Set 7 | roma
# Processing Record 37 of Set 7 | apolda
# Processing Record 38 of Set 7 | homer
# Processing Record 39 of Set 7 | fortuna
# Processing Record 40 of Set 7 | nchelenge
# Processing Record 41 of Set 7 | huarmey
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | bantry
# Processing Record 45 of Set 7 | garowe
# Processing Record 46 of Set 7 | verkhnevilyuysk
# Processing Record 47 of Set 7 | darnah
# Processing Record 48 of Set 7 | neryungri
# Processing Record 49 of Set 7 | duluth
# Processing Record 50 of Set 7 | olafsvik
# Processing Record 1 of Set 8 | mezhdurechensk
# Processing Record 2 of Set 8 | aasiaat
# Processing Record 3 of Set 8 | galesong
# Processing Record 4 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 8 | olenino
# Processing Record 6 of Set 8 | hofn
# Processing Record 7 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 8 | torres
# Processing Record 9 of Set 8 | ejido
# Processing Record 10 of Set 8 | tessalit
# Processing Record 11 of Set 8 | carutapera
# Processing Record 12 of Set 8 | namibe
# Processing Record 13 of Set 8 | lompoc
# Processing Record 14 of Set 8 | hamilton
# Processing Record 15 of Set 8 | statesville
# Processing Record 16 of Set 8 | taltal
# Processing Record 17 of Set 8 | arroyo
# Processing Record 18 of Set 8 | mandera
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | lugovoy
# Processing Record 21 of Set 8 | coquimbo
# Processing Record 22 of Set 8 | sao filipe
# Processing Record 23 of Set 8 | naze
# Processing Record 24 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 8 | bubaque
# Processing Record 26 of Set 8 | kapit
# Processing Record 27 of Set 8 | urumqi
# Processing Record 28 of Set 8 | khingansk
# Processing Record 29 of Set 8 | lata
# Processing Record 30 of Set 8 | morbach
# Processing Record 31 of Set 8 | tshane
# Processing Record 32 of Set 8 | seymchan
# Processing Record 33 of Set 8 | itabera
# Processing Record 34 of Set 8 | hay river
# Processing Record 35 of Set 8 | svetlogorsk
# Processing Record 36 of Set 8 | pombas
# Processing Record 37 of Set 8 | dauphin
# Processing Record 38 of Set 8 | liverpool
# Processing Record 39 of Set 8 | bengkulu
# Processing Record 40 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 8 | clarence town
# Processing Record 42 of Set 8 | byron bay
# Processing Record 43 of Set 8 | bonthe
# Processing Record 44 of Set 8 | emerald
# Processing Record 45 of Set 8 | west wendover
# Processing Record 46 of Set 8 | antofagasta
# Processing Record 47 of Set 8 | kyabe
# Processing Record 48 of Set 8 | puerto carreno
# Processing Record 49 of Set 8 | port victoria
# Processing Record 50 of Set 8 | port blair
# Processing Record 1 of Set 9 | shelopugino
# Processing Record 2 of Set 9 | bafra
# Processing Record 3 of Set 9 | wewak
# Processing Record 4 of Set 9 | hounde
# Processing Record 5 of Set 9 | kindu
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | vao
# Processing Record 8 of Set 9 | katsuura
# Processing Record 9 of Set 9 | chulman
# Processing Record 10 of Set 9 | murray bridge
# Processing Record 11 of Set 9 | kutum
# Processing Record 12 of Set 9 | ardahan
# Processing Record 13 of Set 9 | nkhotakota
# Processing Record 14 of Set 9 | lasa
# Processing Record 15 of Set 9 | beringovskiy
# Processing Record 16 of Set 9 | kualakapuas
# Processing Record 17 of Set 9 | varnamo
# Processing Record 18 of Set 9 | we
# City not found. Skipping...
# Processing Record 19 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 9 | moba
# Processing Record 21 of Set 9 | dabat
# Processing Record 22 of Set 9 | turayf
# Processing Record 23 of Set 9 | bundaberg
# Processing Record 24 of Set 9 | lalin
# Processing Record 25 of Set 9 | gisenyi
# Processing Record 26 of Set 9 | mount gambier
# Processing Record 27 of Set 9 | jos
# Processing Record 28 of Set 9 | isla vista
# Processing Record 29 of Set 9 | thaba nchu
# Processing Record 30 of Set 9 | zhigansk
# Processing Record 31 of Set 9 | belyy yar
# Processing Record 32 of Set 9 | seddon
# Processing Record 33 of Set 9 | omboue
# Processing Record 34 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 35 of Set 9 | mehamn
# Processing Record 36 of Set 9 | johnstown
# Processing Record 37 of Set 9 | kukuna
# Processing Record 38 of Set 9 | xuanzhou
# Processing Record 39 of Set 9 | bonavista
# Processing Record 40 of Set 9 | knyaze-volkonskoye
# Processing Record 41 of Set 9 | yabrud
# Processing Record 42 of Set 9 | bela vista do paraiso
# Processing Record 43 of Set 9 | merauke
# Processing Record 44 of Set 9 | rehoboth
# Processing Record 45 of Set 9 | calvia
# Processing Record 46 of Set 9 | qasigiannguit
# Processing Record 47 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 9 | mao
# Processing Record 49 of Set 9 | palivere
# Processing Record 50 of Set 9 | oktyabrskoye
# Processing Record 1 of Set 10 | labytnangi
# Processing Record 2 of Set 10 | sovetskiy
# Processing Record 3 of Set 10 | yarmouth
# Processing Record 4 of Set 10 | olinda
# Processing Record 5 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 6 of Set 10 | atar
# Processing Record 7 of Set 10 | panvel
# Processing Record 8 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 10 | buraydah
# Processing Record 10 of Set 10 | tual
# Processing Record 11 of Set 10 | hornepayne
# Processing Record 12 of Set 10 | hatta
# Processing Record 13 of Set 10 | aztec
# Processing Record 14 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 15 of Set 10 | tsiroanomandidy
# Processing Record 16 of Set 10 | jennings
# Processing Record 17 of Set 10 | penzance
# Processing Record 18 of Set 10 | ust-kuyga
# Processing Record 19 of Set 10 | siniscola
# Processing Record 20 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 10 | saint-augustin
# Processing Record 22 of Set 10 | lazaro cardenas
# Processing Record 23 of Set 10 | rognan
# Processing Record 24 of Set 10 | aksarka
# Processing Record 25 of Set 10 | ust-tarka
# Processing Record 26 of Set 10 | ca mau
# Processing Record 27 of Set 10 | cayenne
# Processing Record 28 of Set 10 | imbituba
# Processing Record 29 of Set 10 | santa maria
# Processing Record 30 of Set 10 | zeya
# Processing Record 31 of Set 10 | amuntai
# Processing Record 32 of Set 10 | prince george
# Processing Record 33 of Set 10 | berbera
# Processing Record 34 of Set 10 | sechura
# Processing Record 35 of Set 10 | mayo
# Processing Record 36 of Set 10 | amahai
# Processing Record 37 of Set 10 | mitsamiouli
# Processing Record 38 of Set 10 | cuamba
# Processing Record 39 of Set 10 | kavaratti
# Processing Record 40 of Set 10 | cap malheureux
# Processing Record 41 of Set 10 | le pont-de-claix
# Processing Record 42 of Set 10 | belgrade
# Processing Record 43 of Set 10 | harlingen
# Processing Record 44 of Set 10 | grand gaube
# Processing Record 45 of Set 10 | kloulklubed
# Processing Record 46 of Set 10 | vieques
# Processing Record 47 of Set 10 | orlik
# Processing Record 48 of Set 10 | san ramon
# Processing Record 49 of Set 10 | portland
# Processing Record 50 of Set 10 | hobyo
# Processing Record 1 of Set 11 | udachnyy
# Processing Record 2 of Set 11 | dingtao
# Processing Record 3 of Set 11 | holme
# Processing Record 4 of Set 11 | tura
# Processing Record 5 of Set 11 | gao
# Processing Record 6 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 7 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 11 | mindelo
# Processing Record 9 of Set 11 | zbarazh
# Processing Record 10 of Set 11 | berkakit
# Processing Record 11 of Set 11 | sena madureira
# Processing Record 12 of Set 11 | achalpur
# Processing Record 13 of Set 11 | broken hill
# Processing Record 14 of Set 11 | milton
# Processing Record 15 of Set 11 | saint-francois
# Processing Record 16 of Set 11 | chara
# Processing Record 17 of Set 11 | mackay
# Processing Record 18 of Set 11 | doha
# Processing Record 19 of Set 11 | yuncheng
# Processing Record 20 of Set 11 | harduaganj
# Processing Record 21 of Set 11 | mbanza-ngungu
# Processing Record 22 of Set 11 | bereda
# Processing Record 23 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 11 | bandarbeyla
# Processing Record 25 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 11 | saquena
# Processing Record 27 of Set 11 | fare
# Processing Record 28 of Set 11 | garden city
# Processing Record 29 of Set 11 | fort nelson
# Processing Record 30 of Set 11 | mwene-ditu
# Processing Record 31 of Set 11 | maceio
# Processing Record 32 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 33 of Set 11 | san pedro
# Processing Record 34 of Set 11 | shirokiy
# Processing Record 35 of Set 11 | jidong
# Processing Record 36 of Set 11 | kautokeino
# Processing Record 37 of Set 11 | port-gentil
# Processing Record 38 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 11 | saint-georges
# Processing Record 40 of Set 11 | wanxian
# Processing Record 41 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 42 of Set 11 | antropovo
# Processing Record 43 of Set 11 | bereznik
# Processing Record 44 of Set 11 | te anau
# Processing Record 45 of Set 11 | sahy
# Processing Record 46 of Set 11 | mantua
# Processing Record 47 of Set 11 | pattani
# Processing Record 48 of Set 11 | aykhal
# Processing Record 49 of Set 11 | waitati
# Processing Record 50 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 1 of Set 12 | lahr
# Processing Record 2 of Set 12 | isla mujeres
# Processing Record 3 of Set 12 | labuhan
# Processing Record 4 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 12 | mattru
# Processing Record 6 of Set 12 | valparaiso
# Processing Record 7 of Set 12 | selikhino
# Processing Record 8 of Set 12 | kuhdasht
# Processing Record 9 of Set 12 | acarau
# Processing Record 10 of Set 12 | kyzyl-suu
# Processing Record 11 of Set 12 | shihezi
# Processing Record 12 of Set 12 | kidal
# Processing Record 13 of Set 12 | maraba
# Processing Record 14 of Set 12 | suntar
# Processing Record 15 of Set 12 | moose factory
# Processing Record 16 of Set 12 | luwuk
# Processing Record 17 of Set 12 | north bend
# Processing Record 18 of Set 12 | boende
# Processing Record 19 of Set 12 | wilnsdorf
# Processing Record 20 of Set 12 | tallahassee
# Processing Record 21 of Set 12 | yeppoon
# Processing Record 22 of Set 12 | gannan
# Processing Record 23 of Set 12 | mikhaylovka
# Processing Record 24 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing Record 25 of Set 12 | pangai
# Processing Record 26 of Set 12 | zharkent
# Processing Record 27 of Set 12 | cururupu
# Processing Record 28 of Set 12 | gayny
# Processing Record 29 of Set 12 | le vauclin
# Processing Record 30 of Set 12 | parczew
# Processing Record 31 of Set 12 | fairlie
# Processing Record 32 of Set 12 | broome
# Processing Record 33 of Set 12 | qaqortoq
# Processing Record 34 of Set 12 | teruel
# Processing Record 35 of Set 12 | axim
# Processing Record 36 of Set 12 | miraflores
# Processing Record 37 of Set 12 | aranos
# Processing Record 38 of Set 12 | pumiao
# Processing Record 39 of Set 12 | colares
# Processing Record 40 of Set 12 | haputale
# Processing Record 41 of Set 12 | sarangani
# Processing Record 42 of Set 12 | nicholasville
# Processing Record 43 of Set 12 | garut
# Processing Record 44 of Set 12 | khasan
# Processing Record 45 of Set 12 | contamana
# Processing Record 46 of Set 12 | rancho veloz
# Processing Record 47 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 48 of Set 12 | mazyr
# Processing Record 49 of Set 12 | riyadh
# Processing Record 50 of Set 12 | juneau
# Processing Record 1 of Set 13 | port angeles
# Processing Record 2 of Set 13 | houma
# Processing Record 3 of Set 13 | niamtougou
# Processing Record 4 of Set 13 | carbonear
# Processing Record 5 of Set 13 | coari
# Processing Record 6 of Set 13 | maldonado
# Processing Record 7 of Set 13 | togur
# Processing Record 8 of Set 13 | racine
# Processing Record 9 of Set 13 | guarapari
# Processing Record 10 of Set 13 | alma
# Processing Record 11 of Set 13 | gantt
# Processing Record 12 of Set 13 | tunxi
# City not found. Skipping...
# Processing Record 13 of Set 13 | vostok
# Processing Record 14 of Set 13 | placido de castro
# Processing Record 15 of Set 13 | goose creek
# Processing Record 16 of Set 13 | anloga
# Processing Record 17 of Set 13 | sorland
# Processing Record 18 of Set 13 | comodoro rivadavia
# Processing Record 19 of Set 13 | kalmunai
# Processing Record 20 of Set 13 | marathon
# Processing Record 21 of Set 13 | salinas
# Processing Record 22 of Set 13 | te kauwhata
# Processing Record 23 of Set 13 | half moon bay
# Processing Record 24 of Set 13 | cheney
# Processing Record 25 of Set 13 | dunedin
# Processing Record 26 of Set 13 | srivardhan
# Processing Record 27 of Set 13 | mayumba
# Processing Record 28 of Set 13 | evensk
# Processing Record 29 of Set 13 | natal
# Processing Record 30 of Set 13 | xining
# Processing Record 31 of Set 13 | chengde
# Processing Record 32 of Set 13 | drayton valley
# Processing Record 33 of Set 13 | birobidzhan
# Processing Record 34 of Set 13 | korfovskiy
# Processing Record 35 of Set 13 | linden
# Processing Record 36 of Set 13 | yangambi
# Processing Record 37 of Set 13 | husavik
# Processing Record 38 of Set 13 | oparino
# Processing Record 39 of Set 13 | nuuk
# Processing Record 40 of Set 13 | karratha
# Processing Record 41 of Set 13 | waynesville
# Processing Record 42 of Set 13 | jiayuguan
# Processing Record 43 of Set 13 | cedar city
# Processing Record 44 of Set 13 | media luna
# Processing Record 45 of Set 13 | calvinia
# Processing Record 46 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 13 | pahrump
# Processing Record 48 of Set 13 | mackenzie
# Processing Record 49 of Set 13 | rio grande
# Processing Record 50 of Set 13 | penne
# Processing Record 1 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 14 | neuquen
# Processing Record 3 of Set 14 | carauari
# Processing Record 4 of Set 14 | chemainus
# Processing Record 5 of Set 14 | lakes entrance
# Processing Record 6 of Set 14 | bardiyah
# Processing Record 7 of Set 14 | camopi
# Processing Record 8 of Set 14 | chicama
# Processing Record 9 of Set 14 | loei
# Processing Record 10 of Set 14 | ormara
# Processing Record 11 of Set 14 | hirado
# Processing Record 12 of Set 14 | siavonga
# Processing Record 13 of Set 14 | zsambok
# Processing Record 14 of Set 14 | svetlaya
# Processing Record 15 of Set 14 | la gaulette
# City not found. Skipping...
# Processing Record 16 of Set 14 | asau
# Processing Record 17 of Set 14 | canakkale
# Processing Record 18 of Set 14 | volgorechensk
# Processing Record 19 of Set 14 | sibiti
# Processing Record 20 of Set 14 | saint anthony
# Processing Record 21 of Set 14 | aswan
# Processing Record 22 of Set 14 | lagoa
# Processing Record 23 of Set 14 | praia da vitoria
# Processing Record 24 of Set 14 | nador
# Processing Record 25 of Set 14 | vanimo
# Processing Record 26 of Set 14 | moron
# Processing Record 27 of Set 14 | minab
# Processing Record 28 of Set 14 | iguguno
# Processing Record 29 of Set 14 | balakhninskiy
# Processing Record 30 of Set 14 | gamba
# Processing Record 31 of Set 14 | deutschlandsberg
# Processing Record 32 of Set 14 | ostersund
# Processing Record 33 of Set 14 | sao gabriel da cachoeira
# Processing Record 34 of Set 14 | estevan
# Processing Record 35 of Set 14 | mountain home
# Processing Record 36 of Set 14 | ucluelet
# Processing Record 37 of Set 14 | bairiki
# Processing Record 38 of Set 14 | amapa
# Processing Record 39 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 14 | wanning
# Processing Record 41 of Set 14 | narrabri
# Processing Record 42 of Set 14 | kaeo
# Processing Record 43 of Set 14 | buarcos
# Processing Record 44 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 14 | cepu
# Processing Record 46 of Set 14 | shakiso
# Processing Record 47 of Set 14 | puerto del rosario
# Processing Record 48 of Set 14 | brawley
# Processing Record 49 of Set 14 | prado
# Processing Record 50 of Set 14 | koygorodok
# Processing Record 1 of Set 15 | belmonte
# Processing Record 2 of Set 15 | pacific grove
# Processing Record 3 of Set 15 | itaituba
# Processing Record 4 of Set 15 | campos altos
# Processing Record 5 of Set 15 | montepuez
# Processing Record 6 of Set 15 | dourbali
# Processing Record 7 of Set 15 | maniitsoq
# Processing Record 8 of Set 15 | avera
# Processing Record 9 of Set 15 | nagorsk
# Processing Record 10 of Set 15 | lighthouse point
# Processing Record 11 of Set 15 | laguna
# Processing Record 12 of Set 15 | agirish
# Processing Record 13 of Set 15 | tres pontas
# Processing Record 14 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 15 | goias
# Processing Record 16 of Set 15 | emborion
# Processing Record 17 of Set 15 | tilichiki
# Processing Record 18 of Set 15 | jaru
# Processing Record 19 of Set 15 | ust-ilimsk
# Processing Record 20 of Set 15 | ghanzi
# Processing Record 21 of Set 15 | baiyin
# Processing Record 22 of Set 15 | yermakovskoye
# Processing Record 23 of Set 15 | sola
# Processing Record 24 of Set 15 | sibsagar
# Processing Record 25 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 15 | mana
# Processing Record 27 of Set 15 | egvekinot
# Processing Record 28 of Set 15 | andros town
# Processing Record 29 of Set 15 | muros
# Processing Record 30 of Set 15 | kahului
# Processing Record 31 of Set 15 | general elizardo aquino
# Processing Record 32 of Set 15 | brahmapuri
# City not found. Skipping...
# Processing Record 33 of Set 15 | tarragona
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     48.31        87          75
# 1         Bluff -46.6000  168.3333     62.42        78         100
# 2         Kolga  59.4867   25.6192     32.49        98         100
# 3   Tuktoyaktuk  69.4541 -133.0374      5.00        78         100
# 4   East London -33.0153   27.9116     70.95        86          66
# 5        Atuona  -9.8000 -139.0333     78.78        74          47
# 6    Bredasdorp -34.5322   20.0403     66.36        77         100
# 7     Joshimath  30.5667   79.5667     32.86        27           0
# 8          Hami  42.8000   93.4500     19.69        50         100
# 9    Kaitangata -46.2817  169.8464     67.59        68         100
#
#    Wind Speed Country Current Description
# 0       12.66      CL          light rain
# 1        7.49      NZ     overcast clouds
# 2        2.68      EE          light snow
# 3        9.22      CA     overcast clouds
# 4       14.14      ZA       broken clouds
# 5       21.65      PF    scattered clouds
# 6       11.61      ZA     overcast clouds
# 7        9.69      IN           clear sky
# 8        7.49      CN     overcast clouds
# 9        8.34      NZ     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_names = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=column_names)

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     48.31        87          75
# 1         Bluff      NZ -46.6000  168.3333     62.42        78         100
# 2         Kolga      EE  59.4867   25.6192     32.49        98         100
# 3   Tuktoyaktuk      CA  69.4541 -133.0374      5.00        78         100
# 4   East London      ZA -33.0153   27.9116     70.95        86          66
# 5        Atuona      PF  -9.8000 -139.0333     78.78        74          47
# 6    Bredasdorp      ZA -34.5322   20.0403     66.36        77         100
# 7     Joshimath      IN  30.5667   79.5667     32.86        27           0
# 8          Hami      CN  42.8000   93.4500     19.69        50         100
# 9    Kaitangata      NZ -46.2817  169.8464     67.59        68         100
#
#    Wind Speed Current Description
# 0       12.66          light rain
# 1        7.49     overcast clouds
# 2        2.68          light snow
# 3        9.22     overcast clouds
# 4       14.14       broken clouds
# 5       21.65    scattered clouds
# 6       11.61     overcast clouds
# 7        9.69           clear sky
# 8        7.49     overcast clouds
# 9        8.34     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
